# %%
import pandas as pd
import sys
sys.path.insert(0, '..')
import matplotlib.pyplot as plt
from optServers import getOptServer
# Out:
# /Users/julianvanmeggelen/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
arrivalRate = pd.read_csv('../data/seasonalEpsilonGreedy2/arrivalsPerSecond.csv', header = None, index_col = 0, squeeze = True) 
plt.plot(arrivalRate)
# Out:
# <ipython-input-3-733916837bc5>:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   arrivalRate = pd.read_csv('../data/seasonalEpsilonGreedy2/arrivalsPerSecond.csv', header = None, index_col = 0, squeeze = True)

# %%
series = pd.read_csv('../data/seasonalEpsilonGreedy/totalTimeInSystem.csv', header = None, index_col = 0, squeeze = True) 
plt.hist(series.index, bins = 4*7*24);
# Out:
# <ipython-input-6-d09d943de6f8>:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_csv('../data/seasonalEpsilonGreedy/totalTimeInSystem.csv', header = None, index_col = 0, squeeze = True)

# %%
series = pd.read_csv('../data/seasonalEpsilonGreedy/arrivalEvent.csv', header = None, index_col = 0, squeeze = True) 
plt.hist(series.index, bins = 4*7*24);
# Out:
# <ipython-input-7-3f9b3478ec16>:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_csv('../data/seasonalEpsilonGreedy/arrivalEvent.csv', header = None, index_col = 0, squeeze = True)

# %%
series = pd.read_csv('../data/seasonalEpsilonGreedy2/numberOfServers.csv', header = None, index_col = 0, squeeze = True) 
plt.figure(figsize=(15,5))
plt.plot(series, label='Chosen #servers');
opt = [getOptServer(_) for _ in arrivalRate]
opt = pd.Series(data=opt,index=arrivalRate.index)
plt.xlabel('Time (seconds)')
plt.ylabel('#servers')
plt.plot(opt, label='Optimal');
plt.legend()
# Out:
# <ipython-input-6-4a0ef5b4165d>:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_csv('../data/seasonalEpsilonGreedy2/numberOfServers.csv', header = None, index_col = 0, squeeze = True)

# %%
opt = [getOptServer(_) for _ in arrivalRate]
plt.figure(figsize=(15,5))
plt.plot(opt)

# %%
series = pd.read_csv('reward.csv', header = None, index_col = 0, squeeze = True) 
plt.figure(figsize=(15,5))
plt.plot(series);
# Out:
# <ipython-input-21-38caefc1a594>:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_csv('reward.csv', header = None, index_col = 0, squeeze = True)

# %%
series = pd.read_csv('requestCancelled.csv', header = None, index_col = 0, squeeze = True) 
plt.hist(series.index, bins = 4*7*24);
# Out:
# <ipython-input-14-5fb8e1eeb601>:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_csv('requestCancelled.csv', header = None, index_col = 0, squeeze = True)
